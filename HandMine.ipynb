# %%
#Image prep

# %%
#Run Handprint using URLs from .txt file
# !handprint --service microsoft --from-file "/Users/matthewcook/Dropbox/DS/Burns/HTR/Test3/loc-urls3.txt" --no-grid --extended --output "/Users/matthewcook/Dropbox/DS/Burns/HTR/Test3/Output"

#Duplicate (and rename) .txt output to new folder
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           Welcome to Handprint: HANDwritten Page RecognitIoN Test            ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
# Will apply 1 service (microsoft) to 100 images.
# Will save extended results.
# Will use up to 8 process threads.
# Will use credentials stored in /Users/matthewcook/Library/Application
# Support/Handprint/.
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961154
# Downloading https://ids.lib.harvard.edu/ids/view/44961154
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-1.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-1.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961154
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961151
# Downloading https://ids.lib.harvard.edu/ids/view/44961151
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-2.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-2.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961151
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961145
# Downloading https://ids.lib.harvard.edu/ids/view/44961145
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-3.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-3.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961145
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961141
# Downloading https://ids.lib.harvard.edu/ids/view/44961141
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-4.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-4.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961141
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961140
# Downloading https://ids.lib.harvard.edu/ids/view/44961140
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-5.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-5.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961140
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961137
# Downloading https://ids.lib.harvard.edu/ids/view/44961137
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-6.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-6.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961137
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961135
# Downloading https://ids.lib.harvard.edu/ids/view/44961135
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-7.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-7.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961135
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961125
# Downloading https://ids.lib.harvard.edu/ids/view/44961125
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-8.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-8.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961125
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961119
# Downloading https://ids.lib.harvard.edu/ids/view/44961119
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-9.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-9.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961119
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961107
# Downloading https://ids.lib.harvard.edu/ids/view/44961107
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-10.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-10.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961107
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961104
# Downloading https://ids.lib.harvard.edu/ids/view/44961104
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-11.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-11.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961104
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961103
# Downloading https://ids.lib.harvard.edu/ids/view/44961103
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-12.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-12.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961103
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961098
# Downloading https://ids.lib.harvard.edu/ids/view/44961098
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-13.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-13.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961098
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961081
# Downloading https://ids.lib.harvard.edu/ids/view/44961081
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-14.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-14.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961081
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961079
# Downloading https://ids.lib.harvard.edu/ids/view/44961079
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-15.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-15.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961079
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961077
# Downloading https://ids.lib.harvard.edu/ids/view/44961077
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-16.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-16.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961077
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961076
# Downloading https://ids.lib.harvard.edu/ids/view/44961076
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-17.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-17.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961076
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961068
# Downloading https://ids.lib.harvard.edu/ids/view/44961068
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-18.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-18.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961068
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961067
# Downloading https://ids.lib.harvard.edu/ids/view/44961067
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-19.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-19.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961067
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961064
# Downloading https://ids.lib.harvard.edu/ids/view/44961064
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-20.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-20.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961064
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961062
# Downloading https://ids.lib.harvard.edu/ids/view/44961062
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-21.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-21.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961062
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961060
# Downloading https://ids.lib.harvard.edu/ids/view/44961060
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-22.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-22.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961060
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961058
# Downloading https://ids.lib.harvard.edu/ids/view/44961058
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-23.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-23.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961058
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961056
# Downloading https://ids.lib.harvard.edu/ids/view/44961056
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-24.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-24.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961056
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961055
# Downloading https://ids.lib.harvard.edu/ids/view/44961055
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-25.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-25.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961055
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961053
# Downloading https://ids.lib.harvard.edu/ids/view/44961053
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-26.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-26.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961053
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961051
# Downloading https://ids.lib.harvard.edu/ids/view/44961051
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-27.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-27.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961051
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961044
# Downloading https://ids.lib.harvard.edu/ids/view/44961044
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-28.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-28.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961044
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961043
# Downloading https://ids.lib.harvard.edu/ids/view/44961043
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-29.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-29.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44961043
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44961038
# Downloading https://ids.lib.harvard.edu/ids/view/44961038
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-30.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document
jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44960838
# ────────────────────────────────────────────────────────────────────────────────
# Starting on https://ids.lib.harvard.edu/ids/view/44960837
# Downloading https://ids.lib.harvard.edu/ids/view/44960837
# Wrote URL to Dropbox/DS/Burns/HTR/Test3/Output/document-100.url
# Converting to png format: Dropbox/DS/Burns/HTR/Test3/Output/document-100.jpeg
# Sending to microsoft and waiting for response ...
# Got result from microsoft.
# Creating annotated image for microsoft.
# Saving all data for microsoft.
# Saving extracted text for microsoft.
# Done with https://ids.lib.harvard.edu/ids/view/44960837
# ────────────────────────────────────────────────────────────────────────────────
# Done.

# %%
####Bag-of-Words txt output and string search from HandPrint transcriptions. MNC - 5/21
###Built to work with HandPrint, by Mike Hucka: 

import os
import sys
import re

#paths
cardPath = '/Users/matthewcook/Dropbox/DS/Burns/HTR/Test3/loc-urls3.txt'#urls
outPath = '/Users/matthewcook/Dropbox/DS/Burns/HTR/Test3/Output' #output 
textOut = '/Users/matthewcook/Dropbox/DS/Burns/HTR/Test3/BoW.txt'#Bag-of-Words
searchOut = '/Users/matthewcook/Dropbox/DS/Burns/HTR/Test3/refined'#user search output
listFiles = os.listdir(outPath)
count = 0

#declarations
headers = [] 
transcriptions = []
BoW = open(textOut, "a")

#user search
search = open(searchOut, "a")
inputString = input("Search document for: ")
inputString = str(inputString)

#generate header list
with open (cardPath, 'rt') as myfile: 
    for line in myfile:
        headers.append(line)

#append headers and transcriptions to bag-of-words 
for file in sorted (listFiles):
    if not file.startswith('.') and file.endswith (".handprint-microsoft.txt"):
        BoW.write(headers[count]) #write card location to disk
        #print("\n")
        #print((headers[count]))
        contents = open(outPath + "/document-" + str(count + 1) + ".handprint-microsoft.txt", "r") #read card transcription
        transcriptions.append(contents.read())
        #print(transcriptions[count])
        #print("\n")
        BoW.write(transcriptions[count]) #write transcriptions to disk
        BoW.write("\n")
        count = count + 1
        #print("\n")    
BoW.close()


#search
BoW = open(textOut, "r")
count = 0

while count < len(headers):
    if inputString in transcriptions[count]:
        print(headers[count])
        print(transcriptions[count])
        search.write("\n")
        search.write(headers[count])
        search.write(transcriptions[count])
        search.write("\n")
        print("\n")
        count = count + 1
    elif inputString not in transcriptions[count]:
        #print("\n")
        print("No such string found in transcription " + str(count))
        #print("\n")
        count = count + 1
search.close()

print("\n")
print("have a nice day")
        
###To DO
### more inclusive search
### new line in BoW, between cards
### LocateXT integration
# Out:
# Search document for: Walling
# https://ids.lib.harvard.edu/ids/view/44961154
#
# 2.
# 63764
# 3532
# 1853
# . W3 Walling, Henry ] Francis], 1825-1888
# Map of the town of Billerica, Middlesex county,
# Massachusetts, surveyed by order of the town.
# Boston, H.F. Walling, 1853.
# Scale 1:15,000
#
#
# No such string found in transcription 1
# No such string found in transcription 2
# No such string found in transcription 3
# No such string found in transcription 4
# No such string found in transcription 5
# No such string found in transcription 6
# No such string found in transcription 7
# No such string found in transcription 8
# No such string found in transcription 9
# No such string found in transcription 10
# No such string found in transcription 11
# No such string found in transcription 12
# No such string found in transcription 13
# No such string found in transcription 14
# No such string found in transcription 15
# No such string found in transcription 16
# No such string found in transcription 17
# No such string found in transcription 18
# No such string found in transcription 19
# No such string found in transcription 20
# No such string found in transcription 21
# https://ids.lib.harvard.edu/ids/view/44961058
#
# G 3763
# Walling, Henry Francis
# .MS
# 1856
# w3 Map of Middlesex County,
# Massachusetts
#
#
# No such string found in transcription 23
# No such string found in transcription 24
# No such string found in transcription 25
# No such string found in transcription 26
# No such string found in transcription 27
# No such string found in transcription 28
# https://ids.lib.harvard.edu/ids/view/44961038
#
# 63763
# TOUOF
# . 134
# 1858
# , w3Walling, Henry Francis], 1825-1888
# Map of the county of Berkshire, Massachusetts,
# based upon the trigonometrical survey of the
# state, the details from actual surveys under
# the direction of Henry F. Walling, sup.t of the
# Boston and New York, Smith, Gallup
# state map.
# & co. , 1858.
# Scale 1:50,688
#
#
# No such string found in transcription 30
# https://ids.lib.harvard.edu/ids/view/44961036
#
# G3763
# *
# . 83
# 1858
# Walling, Henry Francis], 1825-1888
# W3*
# Map of the counties of Barnstable, Dukes and
# Nantucket, Massachusetts, based upon the trigono-
# metrical survey of the state, the details from
# actual surveys under the direction of Henry F.
# Walling, sup.t of the state map. Boston and New
# York, D.R. Smith & co ., 1858.
# Scale 1:63,360
#
#
# No such string found in transcription 32
# No such string found in transcription 33
# No such string found in transcription 34
# No such string found in transcription 35
# No such string found in transcription 36
# No such string found in transcription 37
# No such string found in transcription 38
# No such string found in transcription 39
# No such string found in transcription 40
# No such string found in transcription 41
# https://ids.lib.harvard.edu/ids/view/44960997
#
# 63763
# 365
# . 37
# 1871
# Bristol county. [Boston, H.F. Walling, 186-?]
# W 3
# Scale 1:158,400
# Pages 28-29 of an unidentified atlas.
#
#
# https://ids.lib.harvard.edu/ids/view/44960996
#
# 63763
# c
# . 87
# 1858
# Walling, Henry Francis], 1825-1888
# . w3
# Map of the county of Bristol, Massachusetts,
# based upon the trigonometrical survey of the
# state, the details from actual surveys under the
# direction of Henry F. Walling, sup.t of the state
# map. New York, John L. Smith & co ., 1858.
# Scale 1:47,520
#
#
# No such string found in transcription 44
# No such string found in transcription 45
# No such string found in transcription 46
# No such string found in transcription 47
# No such string found in transcription 48
# No such string found in transcription 49
# No such string found in transcription 50
# No such string found in transcription 51
# No such string found in transcription 52
# No such string found in transcription 53
# No such string found in transcription 54
# No such string found in transcription 55
# No such string found in transcription 56
# No such string found in transcription 57
# No such string found in transcription 58
# No such string found in transcription 59
# No such string found in transcription 60
# No such string found in transcription 61
# No such string found in transcription 62
# No such string found in transcription 63
# No such string found in transcription 64
# No such string found in transcription 65
# No such string found in transcription 66
# No such string found in transcription 67
# No such string found in transcription 68
# No such string found in transcription 69
# No such string found in transcription 70
# No such string found in transcription 71
# No such string found in transcription 72
# No such string found in transcription 73
# No such string found in transcription 74
# No such string found in transcription 75
# No such string found in transcription 76
# No such string found in transcription 77
# No such string found in transcription 78
# No such string found in transcription 79
# No such string found in transcription 80
# No such string found in transcription 81
# No such string found in transcription 82
# No such string found in transcription 83
# No such string found in transcription 84
# No such string found in transcription 85
# No such string found in transcription 86
# No such string found in transcription 87
# No such string found in transcription 88
# No such string found in transcription 89
# No such string found in transcription 90
# No such string found in transcription 91
# No such string found in transcription 92
# No such string found in transcription 93
# No such string found in transcription 94
# No such string found in transcription 95
# No such string found in transcription 96
# No such string found in transcription 97
# No such string found in transcription 98
# No such string found in transcription 99
#
#
# have a nice day

# %%
### text mining/topic modeling
import gensim
import nltk

#tokenize
# Out:
#   File "<ipython-input-32-efea6e0e8e25>", line 6
#     print("Processing complete on " + fileName)
#     ^
# IndentationError: unexpected indent
